# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 60 kB 8.5 MB/s
# ...
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Renin**

# %%
# Target search for renin
target = new_client.target
target_query = target.search('renin')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references               organism  \
# 0  [{'xref_id': 'P00797', 'xref_name': None, 'xre...           Homo sapiens
# 1  [{'xref_id': 'P06281', 'xref_name': None, 'xre...           Mus musculus
# 2                                                 []  Oryctolagus cuniculus
# 3  [{'xref_id': 'P08424', 'xref_name': None, 'xre...      Rattus norvegicus
# 4  [{'xref_id': 'Q9TSZ1', 'xref_name': None, 'xre...     Callithrix jacchus
# 5                                                 []         Macaca mulatta
# 6                                                 []    Macaca fascicularis
#
#   pref_name  score  species_group_flag target_chembl_id  \
# 0     Renin   29.0               False        CHEMBL286
# 1     Renin   19.0               False       CHEMBL2615
# 2     Renin   18.0               False    CHEMBL1287632
# 3     Renin   17.0               False       CHEMBL2322
# 4     Renin   17.0               False       CHEMBL6056
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Renin* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Renin*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL286'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Renin* (CHEMBL286) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 0                None        32901
# 1                None        32902
# 2                None        32905
# 3                None        32906
# 4                None        34126
# ...               ...          ...
# 4453             None     18456320
# 4454             None     19000025
# 4455             None     19000026
# 4456             None     20711560
# 4457             None     22394430
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL803388
# 1                                                    []    CHEMBL803387
# 2                                                    []    CHEMBL803388
# 3                                                    []    CHEMBL803387
# 4                                                    []    CHEMBL803388
# ...                                                 ...             ...
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('renin_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id  \
# 0                None        32901
# 1                None        32902
# 2                None        32905
# 3                None        32906
# 4                None        34126
# ...               ...          ...
# 4453             None     18456320
# 4454             None     19000025
# 4455             None     19000026
# 4456             None     20711560
# 4457             None     22394430
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL803388
# 1                                                    []    CHEMBL803387
# 2                                                    []    CHEMBL803388
# 3                                                    []    CHEMBL803387
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3044

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None        32901
# 2                None        32905
# 4                None        34126
# 6                None        34128
# 8                None        34435
# ...               ...          ...
# 4426             None     18456293
# 4427             None     18456294
# 4454             None     19000025
# 4455             None     19000026
# 4457             None     22394430
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL803388
# 2                                                    []    CHEMBL803388
# 4                                                    []    CHEMBL803388
# 6                                                    []    CHEMBL803388
# 8                                                    []    CHEMBL801674
# ...                                                 ...             ...
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL47918  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 2           CHEMBL50217  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 4          CHEMBL301347  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 6           CHEMBL48624  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 8          CHEMBL101874  CC[C@H](C)[C@H](NC(=O)[C@@H](NC(=O)[C@H](CC(C)...
# ...                 ...                                                ...
# 4426      CHEMBL4210995  CCc1cccc(-c2c(F)cccc2C(O)(CCCNC(=O)OC)[C@@H]2C...
# 4427      CHEMBL4212859  CCc1cccc(-c2c(F)cccc2C(O)(CCCNC(=O)OC)[C@@H]2C...
# 4454      CHEMBL4560579  C#CCOc1cnc(C(=O)Nc2cc(F)c(F)c([C@@]3(C)N=C(N)S...
# 4455      CHEMBL4577527  C#CCOc1cnc(C(=O)Nc2cc(F)c(F)c([C@@]3(C)N=C(N)S...
# 4457      CHEMBL4762370  CC(C)CN(C[C@H](O)[C@@H](N)c1ccccc1)S(=O)(=O)c1...
#
#      standard_value
# 0              30.0
# 2               2.2
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('renin_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('renin_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL47918  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 1           CHEMBL50217  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 2          CHEMBL301347  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 3           CHEMBL48624  CCCC[C@H](O[C@@H](Cc1ccccc1)C(=O)N1CCC(OCOC)CC...
# 4          CHEMBL101874  CC[C@H](C)[C@H](NC(=O)[C@@H](NC(=O)[C@H](CC(C)...
# ...                 ...                                                ...
# 3039      CHEMBL4210995  CCc1cccc(-c2c(F)cccc2C(O)(CCCNC(=O)OC)[C@@H]2C...
# 3040      CHEMBL4212859  CCc1cccc(-c2c(F)cccc2C(O)(CCCNC(=O)OC)[C@@H]2C...
# 3041      CHEMBL4560579  C#CCOc1cnc(C(=O)Nc2cc(F)c(F)c([C@@]3(C)N=C(N)S...
# 3042      CHEMBL4577527  C#CCOc1cnc(C(=O)Nc2cc(F)c(F)c([C@@]3(C)N=C(N)S...
# 3043      CHEMBL4762370  CC(C)CN(C[C@H](O)[C@@H](N)c1ccccc1)S(=O)(=O)c1...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('renin_03_bioactivity_data_curated.csv', index=False)

# %%
! zip renin.zip *.csv
# Out:
#   adding: renin_01_bioactivity_data_raw.csv (deflated 92%)
#   adding: renin_02_bioactivity_data_preprocessed.csv (deflated 87%)
#   adding: renin_03_bioactivity_data_curated.csv (deflated 87%)

# %%
! ls -l
# Out:
# total 3288
# -rw-r--r-- 1 root root 2381417 Sep 25 11:53 renin_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  330626 Sep 25 11:53 renin_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  354062 Sep 25 11:53 renin_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  288137 Sep 25 11:53 renin.zip
# drwxr-xr-x 1 root root    4096 Sep 22 13:42 sample_data

# %% [markdown]
# ---
